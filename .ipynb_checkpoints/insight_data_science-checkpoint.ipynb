# %%
import os
os.getcwd()
import pandas as pd
import numpy as np
import scipy.stats 
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
# %matplotlib inline

# %%
R2s_AD = pd.read_csv('R2s_mean.csv', na_values=['NA'], index_col=['subject'])
R2s_AD.head(n=5)
# Out:
#          ID  CDR  MMSE   amyloid gender  age  ctx-bankssts  \
# subject
# AD4       1  0.0    30  positive      M   65     19.802828
# AD5       2  0.0    29  negative      F   79     18.342368
# AD6       3  0.0    30  negative      F   74     17.329492
# AD7       4  1.0    26  positive      F   79     21.225398
# AD8       5  0.5    30    unknow      M   72     18.630182
#
#          ctx-caudalanteriorcingulate  ctx-caudalmiddlefrontal  ctx-cuneus  \
# subject
# AD4                        16.415900                18.534888   20.771802
# AD5                        15.692319                17.757124   20.121539
# AD6                        14.064403                15.648128   18.022137
# AD7                        17.714105                20.070420   23.268346
# AD8                        16.043634                16.417473   18.852891
#
#            ...      ctx-cerebellum   thalamus    caudate    putamen  \
# subject    ...
# AD4        ...           17.511120  21.505069  24.580769  28.997537
# AD5        ...           12.492735  20.649328  24.536857  30.475405
# AD6        ...           15.472910  18.774864  18.914193  23.467916
# AD7        ...           18.094276  24.486720  32.167129  41.509962
# AD8        ...           12.705403  21.814847  24.584332  35.125012
#
#           pallidum  hippocampus   amygdala         GM         WM  ab42_stat
# subject
# AD4      36.388054    16.788996  17.833733  19.179176  20.832341          1
# AD5      40.790454    19.010596  16.029070  18.533750  20.827902          0
# AD6      33.918651    16.261647  16.271197  17.040058  18.568596          0
# AD7      51.811002    19.895585  21.588230  21.008977  22.982659          1
# AD8      37.056673    15.026736  20.597741  17.436004  19.687555          0
#
# [5 rows x 51 columns]

# %%
SUVR_all = pd.read_table('suvr.txt', index_col=['subject'])
SUVR_AD = SUVR_all.loc['AD4':'ADRCAG-99',]
SUVR_AD.head(n=5)
# Out:
#          ID  CDR  MMSE   amyloid gender  age  ctx-bankssts  \
# subject
# AD4       1  0.0    30  positive      M   65        1.9865
# AD5       2  0.0    29  negative      F   79        1.1835
# AD6       3  0.0    30  negative      F   74        1.2877
# AD7       4  1.0    26  positive      F   79        2.0076
# AD8       5  0.5    30    unknow      M   72        0.0000
#
#          ctx-caudalanteriorcingulate  ctx-caudalmiddlefrontal  ctx-cuneus  \
# subject
# AD4                           1.9617                   1.9050      1.5356
# AD5                           1.0385                   0.9577      1.0703
# AD6                           1.1414                   1.0726      1.1752
# AD7                           1.8313                   1.5333      1.3737
# AD8                           0.0000                   0.0000      0.0000
#
#             ...       wm-cerebellum  ctx-cerebellum  thalamus  caudate  \
# subject     ...
# AD4         ...              1.5785               1    1.8507   1.6624
# AD5         ...              1.7231               1    1.4238   0.9978
# AD6         ...              1.7347               1    1.5018   1.1264
# AD7         ...              1.6842               1    2.0354   1.8748
# AD8         ...              0.0000               0    0.0000   0.0000
#
#          putamen  pallidum  hippocampus  amygdala  Unnamed: 49  Unnamed: 50
# subject
# AD4       2.0614    1.9042       1.3035    1.3734          NaN          NaN
# AD5       1.3678    1.7491       1.1173    1.2343          NaN          NaN
# AD6       1.4313    1.7780       1.2927    1.2442          NaN          NaN
# AD7       2.0818    1.9877       1.3401    1.3718          NaN          NaN
# AD8       0.0000    0.0000       0.0000    0.0000          NaN          NaN
#
# [5 rows x 50 columns]

# %%
mask= ~(SUVR_AD['amyloid'] == 'unknow')
R2s_data = R2s_AD.ix[mask, 'ctx-bankssts':'amygdala']
SUVR_data = SUVR_AD.ix[mask, 'ctx-bankssts':'amygdala']
print(SUVR_data.shape)
# Out:
# (25, 42)

# %%
paircorr = R2s_data.corrwith(SUVR_data)
plt.figure(figsize=(8, 16))
paircorr.plot.barh()

# %%
SUVR_corr = SUVR_data.corrwith(SUVR_data['ctx-parahippocampal'])
plt.figure(figsize=(8, 16))
SUVR_corr.plot.barh()

# %%
import seaborn as sns
import scipy.stats

# %%
pearson = [scipy.stats.pearsonr(R2s_data[column], SUVR_data[column]) for column in R2s_data]
df_pearson = DataFrame(pearson)

# %%
figs, axes = plt.subplots(6, 7, sharex=False, sharey=True)
figs.set_size_inches(18, 18)
counter = 0
for i in range(6):
    for j in range(7):
        r, p = scipy.stats.pearsonr(R2s_data.iloc[:, counter], SUVR_data.iloc[:, counter])
        sns.regplot(R2s_data.iloc[:, counter], SUVR_data.iloc[:, counter], ax=axes[i, j], color='k')
        axes[i, j].set_xticklabels([''])
        axes[i, j].set_title(R2s_data.columns[counter])
        axes[i, j].set_ylabel('')
        axes[i, j].set_xlabel('')
        axes[i, j].text(0.2, 0.8, 'r=%.2f\np=%.2f' % (r, p), 
                        horizontalalignment='center', 
                        transform=axes[i, j].transAxes)
        counter += 1

# %%
figs, axes = plt.subplots(2, 2)
axes[0, 0].scatter(R2s_data.iloc[:, 1], SUVR_data.iloc[:, 1])
axes[0, 0].set_xlim([8, 20])
axes[0, 0].set_xticklabels([''])
r, p = scipy.stats.pearsonr(R2s_data.iloc[:, 1], SUVR_data.iloc[:, 1])
axes[0, 0].text(0.3, 0.8, 'r=%.2f\np=%.2f' % (r, p), horizontalalignment='center', 
                verticalalignment='center', transform=axes[0, 0].transAxes)
axes[0, 1].text(0.3, 0.8, 'hello\nhi', horizontalalignment='center', 
                verticalalignment='center', transform=axes[0, 1].transAxes)

# %%
pearson = [scipy.stats.pearsonr(R2s_data[column], SUVR_data[column]) for column in R2s_data]
# Out:
# (0.29755122549372581, 0.14858558542429839)

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="30068a64-00a9-446e-b4a2-b7a66bf492c6">Loading BokehJS ...</span>
#     </div>

# %%
import bokeh.plotting
fig = bokeh.plotting.figure()
fig.circle(R2s_data['ctx-parahippocampal'], SUVR_data['ctx-parahippocampal'], legend='R2s/SUVR')
fig.title = 'ctx-parahippocampal R2s vs. SUVR'

# %%
sns.regplot(x=R2s_data['ctx-parahippocampal'], y=SUVR_data['ctx-parahippocampal'])

# %%
frames = [R2s_data, SUVR_data]
result = pd.concat(frames, axis=1, keys=['R2s', 'SUVR'])
